# %%
#QUESTION 1
First = input("enter you first name :")
Last = input("enter your last name :")
print(Last," ",First)

# %%
#QUESTION 2
n = input("Enter a one digit number :")
n1 = int(n)
n2 = int(n+n)
n3 = int(n+n+n)
print(n1+n2+n3)

# %%
#QUESTION 3
num = input("enter a number :")
if int(num) % 2 == 0 :
  print(num," is even")
else :
  print(num," is odd")

# %%
#QUESTION 4
for i in range(2000,3201) :
  if i % 7 == 0 and i % 5 != 0 :
    print(i, end=" "),

# %%
#QUESTION 5
i = input("enter a number ") 
prod = 1 
i = int(i)
if i == 0 :
  print("1")
else :
  while i >= 1 :
    prod = prod * i 
    i = i-1
  print(prod)

# %%
#QUESTION 6
ch = input("enter your word : ")
ch_even =""
for i in range(0,len(ch),2) :
  ch_even = ch_even + ch[i]
print(ch_even)

# %%
#QUESTION 7 
price = input("enter the price :") 
price = int(price)
if price >= 500 :
  print("new price is : ",price -price*0.5)
elif price in range(200,500) :
  print("new price is : ", price -price*0.3)
else : 
  print("new price is : ", price - price*0.1)
# Out:
# enter the price :100
# new price is :  90.0
